# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import requests
import json

# %%
# Read accident CSV file as Pandas DataFrame
accident_df = pd.read_csv(r"Data/accident_FARS.csv")
accident_df
# Out:
# C:\Users\shrey\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (40,42,69) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        STATE STATENAME  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERSONS  \
# 0          1   Alabama    10001         2         2         0     0        3
# 1          1   Alabama    10002         2         2         0     0        2
# 2          1   Alabama    10003         3         3         0     0        4
# 3          1   Alabama    10004         1         1         0     1        1
# 4          1   Alabama    10005         1         1         0     0        1
# ...      ...       ...      ...       ...       ...       ...   ...      ...
# 33239     56   Wyoming   560117         1         1         0     0        1
# 33240     56   Wyoming   560118         5         5         0     0        6
# 33241     56   Wyoming   560119         1         1         0     0        1
# 33242     56   Wyoming   560120         1         1         0     0        2
# 33243     56   Wyoming   560121         2         2         0     0        3
#
#        PERMVIT  PERNOTMVIT  ...  HOSP_MN                        HOSP_MNNAME  \
# 0            3           0  ...       27                                 27
# 1            2           0  ...       99  Unknown EMS Hospital Arrival Time
# 2            4           0  ...        5                                  5
# 3            1           1  ...       88   Not Applicable (Not Transported)
# 4            1           0  ...       88   Not Applicable (Not Transported)
# ...        ...         ...  ...      ...                                ...
# 33239        1           0  ...       99  Unknown EMS Hospital Arrival Time
# 33240        6           0  ...        0                                  0
# 33241        1           0  ...       21                                 21
# 33242        2           0  ...       52                                 52
# 33243        3           0  ...        2                                  2
#
#        CF1                                            CF1NAME  CF2  CF2NAME  \
# 0        0                                               None    0     None
# 1        0                                               None    0     None
# 2       14  Motor Vehicle struck by falling cargo,or somet...    0     None
# 3        0                                               None    0     None
# 4        0                                               None    0     None
# ...    ...                                                ...  ...      ...
# 33239    0                                               None    0     None
# 33240    0                                               None    0     None
# 33241    0                                               None    0     None
# 33242    0                                               None    0     None
# 33243    0                                               None    0     None
#
#        CF3 CF3NAME  FATALS  DRUNK_DR
# 0        0    None       1         1
# 1        0    None       1         0
# 2        0    None       1         0
# 3        0    None       1         0
# 4        0    None       1         1
# ...    ...     ...     ...       ...
# 33239    0    None       1         0
# 33240    0    None       1         0
# 33241    0    None       1         1
# 33242    0    None       1         1
# 33243    0    None       2         1
#
# [33244 rows x 91 columns]

# %%
accident_df.drop(columns = ["STATE", "CITY", "VE_TOTAL", "VE_FORMS", "PVH_INVL", "PEDS", "PERMVIT", 
                                "PERNOTMVIT", "COUNTY", "CITY", "DAY", "DAYNAME", "MONTH", "YEAR", "DAY_WEEK",
                                "HOUR", "HOURNAME", "MINUTE", "MINUTENAME", "NHS", "NHSNAME", "ROUTE",
                                "TWAY_ID", "TWAY_ID2", "RUR_URB", "FUNC_SYS", "RD_OWNER", "RD_OWNERNAME",
                                "MILEPT", "MILEPTNAME", "LATITUDENAME", "LONGITUDNAME", "SP_JUR", "SP_JURNAME",
                                "HARM_EV", "MAN_COLL", "RELJCT1", "RELJCT2", "RELJCT1NAME", "RELJCT2NAME",
                                "TYP_INT", "TYP_INTNAME", "WRK_ZONE", "WRK_ZONENAME", "REL_ROAD", "REL_ROADNAME",
                                "LGT_COND", "WEATHER1", "WEATHER1NAME", "WEATHER2", "WEATHER2NAME",
                                "WEATHER", "SCH_BUS", "SCH_BUSNAME", "RAIL", "RAILNAME", "NOT_HOUR", 
                                "NOT_HOURNAME", "NOT_MIN", "NOT_MINNAME", "ARR_HOUR", "ARR_HOURNAME",
                                "ARR_MIN", "ARR_MINNAME", "HOSP_HR", "HOSP_HRNAME", "HOSP_MN", "HOSP_MNNAME",
                                "CF1", "CF1NAME", "CF2", "CF2NAME", "CF3", "CF3NAME", "FATALS", "DRUNK_DR"], inplace = True)

# %%
accident_df
# Out:
#       STATENAME  ST_CASE  PERSONS       COUNTYNAME        CITYNAME  MONTHNAME  \
# 0       Alabama    10001        3         LEE (81)         OPELIKA   February
# 1       Alabama    10002        2      ETOWAH (55)         GADSDEN    January
# 2       Alabama    10003        4    CLEBURNE (29)  NOT APPLICABLE    January
# 3       Alabama    10004        1      ETOWAH (55)    RAINBOW CITY    January
# 4       Alabama    10005        1      BALDWIN (3)  NOT APPLICABLE    January
# ...         ...      ...      ...              ...             ...        ...
# 33239   Wyoming   560117        1       CROOK (11)           Other  September
# 33240   Wyoming   560118        6       ALBANY (1)  NOT APPLICABLE  September
# 33241   Wyoming   560119        1    SHERIDAN (33)  NOT APPLICABLE  September
# 33242   Wyoming   560120        2     LARAMIE (21)  NOT APPLICABLE  September
# 33243   Wyoming   560121        3  SWEETWATER (37)     GREEN RIVER  September
#
#       DAY_WEEKNAME      ROUTENAME RUR_URBNAME                FUNC_SYSNAME  \
# 0         Thursday     Interstate       Urban                  Interstate
# 1        Wednesday     Interstate       Urban                  Interstate
# 2          Tuesday     Interstate       Rural                  Interstate
# 3          Tuesday     Interstate       Rural                  Interstate
# 4           Friday     Interstate       Urban                  Interstate
# ...            ...            ...         ...                         ...
# 33239     Saturday        Unknown       Rural                       Local
# 33240       Monday  State Highway       Rural              Minor Arterial
# 33241       Sunday  State Highway       Rural                       Local
# 33242       Sunday   U.S. Highway       Rural  Principal Arterial - Other
# 33243       Friday          Other       Urban  Principal Arterial - Other
#
#         LATITUDE    LONGITUD                 HARM_EVNAME  \
# 0      32.666222  -85.336658  Motor Vehicle In-Transport
# 1      33.997828  -86.053997  Motor Vehicle In-Transport
# 2      33.660842  -85.391011  Motor Vehicle In-Transport
# 3      33.956472  -86.140522                  Pedestrian
# 4      30.656269  -87.809461           Rollover/Overturn
# ...          ...         ...                         ...
# 33239  44.354406 -104.810853           Rollover/Overturn
# 33240  41.167136 -105.887706  Motor Vehicle In-Transport
# 33241  44.912142 -107.104503           Rollover/Overturn
# 33242  41.403750 -104.456917                  Embankment
# 33243  41.522656 -109.447392  Motor Vehicle In-Transport
#
#                                             MAN_COLLNAME        LGT_CONDNAME  \
# 0                                          Front-to-Rear            Daylight
# 1                                          Front-to-Rear  Dark - Not Lighted
# 2                                          Front-to-Rear  Dark - Not Lighted
# 3      The First Harmful Event was Not a Collision wi...  Dark - Not Lighted
# 4      The First Harmful Event was Not a Collision wi...  Dark - Not Lighted
# ...                                                  ...                 ...
# 33239  The First Harmful Event was Not a Collision wi...                Dusk
# 33240                                      Front-to-Rear            Daylight
# 33241  The First Harmful Event was Not a Collision wi...            Daylight
# 33242  The First Harmful Event was Not a Collision wi...  Dark - Not Lighted
# 33243                                     Front-to-Front  Dark - Not Lighted
#
#              WEATHERNAME
# 0                  Clear
# 1                   Rain
# 2                 Cloudy
# 3                  Clear
# 4       Fog, Smog, Smoke
# ...                  ...
# 33239  Severe Crosswinds
# 33240              Clear
# 33241              Clear
# 33242              Clear
# 33243               Rain
#
# [33244 rows x 16 columns]
