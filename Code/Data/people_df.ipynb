# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import requests
import json

# %%
# Read CSV file as Pandas Dataframe
person_df = pd.read_csv('Data/Person_FARS.csv', encoding='cp1252')
# Out:
# C:\Users\shrey\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Display the dataframe and filter
person_df.head(10)

pers_df = person_df.filter(['ST_CASE','MAKENAME', 'MAK_MOD', 'AGE', 'SEXNAME', 'DOANAME', 'PER_TYPNAME'], axis=1)
pers_df
# Out:
#        ST_CASE      MAKENAME  \
# 0        10001        Toyota
# 1        10001        Toyota
# 2        10001  Freightliner
# 3        10002           BMW
# 4        10002     Chevrolet
# ...        ...           ...
# 82215   560120       Hyundai
# 82216   560120       Hyundai
# 82217   560121         Dodge
# 82218   560121         Dodge
# 82219   560121         Dodge
#
#                                                  MAK_MOD  AGE SEXNAME  \
# 0                                           Toyota Camry   34  Female
# 1                                           Toyota Camry   53    Male
# 2                        Freightliner Medium/Heavy - CBE   59    Male
# 3                                           BMW 3-series   42  Female
# 4      Chevrolet TrailBlazer (2003 on; for 2002 model...   54  Female
# ...                                                  ...  ...     ...
# 82215                                   Hyundai Santa Fe   31    Male
# 82216                                   Hyundai Santa Fe   22    Male
# 82217  Dodge Dart (2013 on. See model 001 for 1960-19...   42    Male
# 82218  Dodge Dart (2013 on. See model 001 for 1960-19...   41  Female
# 82219                                   Dodge Ram Pickup   30    Male
#
#               DOANAME                                PER_TYPNAME
# 0      Not Applicable     Driver of a Motor Vehicle In-Transport
# 1       Died at Scene  Passenger of a Motor Vehicle In-Transport
# 2      Not Applicable     Driver of a Motor Vehicle In-Transport
# 3       Died at Scene     Driver of a Motor Vehicle In-Transport
# 4      Not Applicable     Driver of a Motor Vehicle In-Transport
# ...               ...                                        ...
# 82215   Died at Scene     Driver of a Motor Vehicle In-Transport
# 82216  Not Applicable  Passenger of a Motor Vehicle In-Transport
# 82217   Died at Scene     Driver of a Motor Vehicle In-Transport
# 82218   Died at Scene  Passenger of a Motor Vehicle In-Transport
# 82219  Not Applicable     Driver of a Motor Vehicle In-Transport
#
# [82220 rows x 7 columns]

# %%
# Remove unnecessary rows
na_pers = pers_df[~pers_df.isin(["NOT APPLICABLE", "Not Reported", "Reported as Unknown", "Other", 999, 998]).any(axis=1)]
na_pers
# Out:
#        ST_CASE      MAKENAME  \
# 0        10001        Toyota
# 1        10001        Toyota
# 2        10001  Freightliner
# 3        10002           BMW
# 4        10002     Chevrolet
# ...        ...           ...
# 82215   560120       Hyundai
# 82216   560120       Hyundai
# 82217   560121         Dodge
# 82218   560121         Dodge
# 82219   560121         Dodge
#
#                                                  MAK_MOD  AGE SEXNAME  \
# 0                                           Toyota Camry   34  Female
# 1                                           Toyota Camry   53    Male
# 2                        Freightliner Medium/Heavy - CBE   59    Male
# 3                                           BMW 3-series   42  Female
# 4      Chevrolet TrailBlazer (2003 on; for 2002 model...   54  Female
# ...                                                  ...  ...     ...
# 82215                                   Hyundai Santa Fe   31    Male
# 82216                                   Hyundai Santa Fe   22    Male
# 82217  Dodge Dart (2013 on. See model 001 for 1960-19...   42    Male
# 82218  Dodge Dart (2013 on. See model 001 for 1960-19...   41  Female
# 82219                                   Dodge Ram Pickup   30    Male
#
#               DOANAME                                PER_TYPNAME
# 0      Not Applicable     Driver of a Motor Vehicle In-Transport
# 1       Died at Scene  Passenger of a Motor Vehicle In-Transport
# 2      Not Applicable     Driver of a Motor Vehicle In-Transport
# 3       Died at Scene     Driver of a Motor Vehicle In-Transport
# 4      Not Applicable     Driver of a Motor Vehicle In-Transport
# ...               ...                                        ...
# 82215   Died at Scene     Driver of a Motor Vehicle In-Transport
# 82216  Not Applicable  Passenger of a Motor Vehicle In-Transport
# 82217   Died at Scene     Driver of a Motor Vehicle In-Transport
# 82218   Died at Scene  Passenger of a Motor Vehicle In-Transport
# 82219  Not Applicable     Driver of a Motor Vehicle In-Transport
#
# [80264 rows x 7 columns]

# %%
only_drivers = na_pers.loc[na_pers['PER_TYPNAME'] == "Driver of a Motor Vehicle In-Transport"]
only_drivers["PER_TYPNAME"].value_counts()
only_drivers.head()
# Out:
#    ST_CASE      MAKENAME                                            MAK_MOD  \
# 0    10001        Toyota                                       Toyota Camry
# 2    10001  Freightliner                    Freightliner Medium/Heavy - CBE
# 3    10002           BMW                                       BMW 3-series
# 4    10002     Chevrolet  Chevrolet TrailBlazer (2003 on; for 2002 model...
# 5    10003         Acura                                       Acura RL/RLX
#
#    AGE SEXNAME         DOANAME                             PER_TYPNAME
# 0   34  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 2   59    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 3   42  Female   Died at Scene  Driver of a Motor Vehicle In-Transport
# 4   54  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 5   22    Male  Not Applicable  Driver of a Motor Vehicle In-Transport

# %%
sc_pers_df = only_drivers.rename(columns={"ST_CASE": "Case_Number", "MAKENAME": "Vehicle_Manufacturer", "MAK_MOD": "Vehicle_Model",
                                             "SEXNAME": "Sex", "DOANAME": "DOA_Status", "PER_TYPNAME": "Passenger_Type"})

cleaned_pers_df = sc_pers_df.replace({'Not Applicable': 'No Fatality', 'Died at Scene': 'Fatal', 'nan': 'No Fatality', 'Died En Route': 'Fatal'})

cleaned_pers_df
# Out:
#        Case_Number Vehicle_Manufacturer  \
# 0            10001               Toyota
# 2            10001         Freightliner
# 3            10002                  BMW
# 4            10002            Chevrolet
# 5            10003                Acura
# ...            ...                  ...
# 82213       560118            Peterbilt
# 82214       560119      Harley-Davidson
# 82215       560120              Hyundai
# 82217       560121                Dodge
# 82219       560121                Dodge
#
#                                            Vehicle_Model  AGE     Sex  \
# 0                                           Toyota Camry   34  Female
# 2                        Freightliner Medium/Heavy - CBE   59    Male
# 3                                           BMW 3-series   42  Female
# 4      Chevrolet TrailBlazer (2003 on; for 2002 model...   54  Female
# 5                                           Acura RL/RLX   22    Male
# ...                                                  ...  ...     ...
# 82213                       Peterbilt Medium/Heavy - CBE   56    Male
# 82214                   Harley-Davidson 750cc or greater   52    Male
# 82215                                   Hyundai Santa Fe   31    Male
# 82217  Dodge Dart (2013 on. See model 001 for 1960-19...   42    Male
# 82219                                   Dodge Ram Pickup   30    Male
#
#         DOA_Status                          Passenger_Type
# 0      No Fatality  Driver of a Motor Vehicle In-Transport
# 2      No Fatality  Driver of a Motor Vehicle In-Transport
# 3            Fatal  Driver of a Motor Vehicle In-Transport
# 4      No Fatality  Driver of a Motor Vehicle In-Transport
# 5      No Fatality  Driver of a Motor Vehicle In-Transport
# ...            ...                                     ...
# 82213  No Fatality  Driver of a Motor Vehicle In-Transport
# 82214  No Fatality  Driver of a Motor Vehicle In-Transport
# 82215        Fatal  Driver of a Motor Vehicle In-Transport
# 82217        Fatal  Driver of a Motor Vehicle In-Transport
# 82219  No Fatality  Driver of a Motor Vehicle In-Transport
#
# [49701 rows x 7 columns]

# %%
# Establish bins for ages

# bins: 1 = 6 - 19; 2 = 19 - 33; 3 = 33 - 46; 4 = 46 - 60; 5 = 60 - 73; 6 = 73 - 87; 7 = 87+

for row in cleaned_pers_df.iteritems():
    cleaned_pers_df['Age_Bin'] = pd.cut(cleaned_pers_df['AGE'],7, precision=0)
    cleaned_pers_df['Age_Label'] = pd.cut(cleaned_pers_df['AGE'],7, precision=0, labels=["1", "2", "3", "4", "5", "6", "7"])

# %%
cleaned_pers_df.head(50)
# Out:
#     Case_Number               Vehicle_Manufacturer  \
# 0         10001                             Toyota
# 2         10001                       Freightliner
# 3         10002                                BMW
# 4         10002                          Chevrolet
# 5         10003                              Acura
# 7         10003   International Harvester/Navistar
# 8         10003                               Ford
# 10        10004                          Peterbilt
# 11        10005                             Toyota
# 12        10006                       Freightliner
# 13        10006                           Kenworth
# 14        10007                                GMC
# 19        10008                               Ford
# 20        10009                               Ford
# 23        10011                              Honda
# 27        10012                              Dodge
# 29        10013                              Honda
# 31        10014  Jeep / Kaiser-Jeep / Willys- Jeep
# 32        10015                               Ford
# 33        10015                       Freightliner
# 34        10016                              Honda
# 35        10016                          Chevrolet
# 36        10016                             Toyota
# 37        10017                             Yamaha
# 38        10017                                KIA
# 40        10018                            Pontiac
# 41        10019                             Yamaha
# 42        10020                               Ford
# 43        10021                              Honda
# 44        10021                          Chevrolet
# 45        10022                               Ford
# 46        10023                          Chevrolet
# 47        10023                                KIA
# 49        10024                             Suzuki
# 50        10025                             Suzuki
# 51        10025                               Ford
# 52        10025                             Toyota
# 53        10026                             Toyota
# 54        10027                               Ford
# 55        10028                               Ford
# 56        10028                             Saturn
# 57        10028                               Ford
# 58        10028                               Ford
# 59        10029                             Toyota
# 60        10030                               Ford
# 61        10031                      Nissan/Datsun
# 62        10031                          Chevrolet
# 63        10032                              Lexus
# 64        10033                            Lincoln
# 65        10033                          Chevrolet
#
#                                         Vehicle_Model  AGE     Sex  \
# 0                                        Toyota Camry   34  Female
# 2                     Freightliner Medium/Heavy - CBE   59    Male
# 3                                        BMW 3-series   42  Female
# 4   Chevrolet TrailBlazer (2003 on; for 2002 model...   54  Female
# 5                                        Acura RL/RLX   22    Male
# 7   International Harvester/Navistar Medium/Heavy ...   22    Male
# 8                                         Ford Fusion   26  Female
# 10                       Peterbilt Medium/Heavy - CBE   41    Male
# 11                                      Toyota Avalon   30    Male
# 12                    Freightliner Medium/Heavy - CBE   54    Male
# 13                        Kenworth Medium/Heavy - CBE   70    Male
# 14                           GMC Fullsize Jimmy/Yukon   68    Male
# 19                               Ford F-Series pickup   50    Male
# 20                                        Ford Escape   66    Male
# 23  Honda Accord (Note: For Crosstour model years ...   38    Male
# 27                                   Dodge Ram Pickup   67  Female
# 29                           Honda Civic/CRX, del Sol   19    Male
# 31  Jeep / Kaiser-Jeep / Willys- Jeep Cherokee (19...   23    Male
# 32                               Ford F-Series pickup   38    Male
# 33                    Freightliner Medium/Heavy - CBE   53    Male
# 34                                         Honda CR-V   77  Female
# 35                                 Chevrolet Colorado   45  Female
# 36                                      Toyota Sienna   63  Female
# 37                                   Yamaha 450-749cc   26    Male
# 38                                        KIA Sorento   74  Female
# 40                                         Pontiac G6   37    Male
# 41                            Yamaha 750cc or greater   57    Male
# 42                               Ford F-Series pickup   52    Male
# 43  Honda Accord (Note: For Crosstour model years ...   62    Male
# 44  Chevrolet Suburban (from 1950-2003;see 422 for...   35    Male
# 45                                         Ford Focus   29    Male
# 46  Chevrolet Impala/Caprice (For SS from 2014 on,...   32  Female
# 47                                          KIA Forte   17    Male
# 49  Suzuki XL-7 (2003 on; see 402 for 2002 model y...   39    Male
# 50                                   Suzuki 450-749cc   16    Male
# 51                            Ford Medium/Heavy - CBE   31    Male
# 52                                      Toyota Tundra   59    Male
# 53                                       Toyota T-100   67    Male
# 54                                    Ford Expedition   17    Male
# 55                               Ford F-Series pickup   33    Male
# 56                                     Saturn Outlook   26  Female
# 57                            Ford Mustang/Mustang II   29    Male
# 58                                       Ford Transit   72    Male
# 59                                    Toyota 4-Runner   24  Female
# 60                               Ford F-Series pickup   60    Male
# 61  Nissan/Datsun Rogue (For 2008-2018 only.  For ...   47  Female
# 62                    Chevrolet Fullsize Blazer/Tahoe   29    Male
# 63                     Lexus ES-250/300/300h/330/ 350   23    Male
# 64           Lincoln Continental (thru `81)/ Town Car   35  Female
# 65  Chevrolet Traverse (2013 on.  For 2009-2012 se...   43  Female
#
#      DOA_Status                          Passenger_Type       Age_Bin  \
# 0   No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 2   No Fatality  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 3         Fatal  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 4   No Fatality  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 5   No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 7   No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 8   No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 10  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 11        Fatal  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 12        Fatal  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 13  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 14  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 19        Fatal  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 20        Fatal  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 23  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 27  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 29  No Fatality  Driver of a Motor Vehicle In-Transport   (6.0, 19.0]
# 31  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 32        Fatal  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 33  No Fatality  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 34  No Fatality  Driver of a Motor Vehicle In-Transport  (73.0, 87.0]
# 35  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 36  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 37        Fatal  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 38  No Fatality  Driver of a Motor Vehicle In-Transport  (73.0, 87.0]
# 40  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 41        Fatal  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 42        Fatal  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 43        Fatal  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 44  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 45        Fatal  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 46  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 47  No Fatality  Driver of a Motor Vehicle In-Transport   (6.0, 19.0]
# 49        Fatal  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 50        Fatal  Driver of a Motor Vehicle In-Transport   (6.0, 19.0]
# 51  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 52  No Fatality  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 53  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 54  No Fatality  Driver of a Motor Vehicle In-Transport   (6.0, 19.0]
# 55        Fatal  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 56  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 57        Fatal  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 58  No Fatality  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 59  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 60        Fatal  Driver of a Motor Vehicle In-Transport  (60.0, 73.0]
# 61        Fatal  Driver of a Motor Vehicle In-Transport  (46.0, 60.0]
# 62  No Fatality  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 63        Fatal  Driver of a Motor Vehicle In-Transport  (19.0, 33.0]
# 64        Fatal  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
# 65  No Fatality  Driver of a Motor Vehicle In-Transport  (33.0, 46.0]
#
#    Age_Label
# 0          3
# 2          4
# 3          3
# 4          4
# 5          2
# 7          2
# 8          2
# 10         3
# 11         2
# 12         4
# 13         5
# 14         5
# 19         4
# 20         5
# 23         3
# 27         5
# 29         1
# 31         2
# 32         3
# 33         4
# 34         6
# 35         3
# 36         5
# 37         2
# 38         6
# 40         3
# 41         4
# 42         4
# 43         5
# 44         3
# 45         2
# 46         2
# 47         1
# 49         3
# 50         1
# 51         2
# 52         4
# 53         5
# 54         1
# 55         3
# 56         2
# 57         2
# 58         5
# 59         2
# 60         5
# 61         4
# 62         2
# 63         2
# 64         3
# 65         3

# %%
cleaned_pers_df["Vehicle_Model"].value_counts()
# Out:
# Ford F-Series pickup                            2182
# Chevrolet C, K, R, V-series pickup/Silverado    2037
# Harley-Davidson 750cc or greater                1908
# Dodge Ram Pickup                                1251
# Freightliner Medium/Heavy - CBE                 1245
#                                                 ...
# Mack Unknown (MACK)                                1
# Isuzu Medium/Heavy - COE, high entry               1
# Dodge Medium/Heavy -Unknown engine location        1
# Unknown Make Motor Home                            1
# Chevrolet Lumina APV                               1
# Name: Vehicle_Model, Length: 900, dtype: int64

# %%
cleaned_pers_df.drop(columns=["Age_Bin"], inplace=True)

# %%
# Writing Accidents final dataframe to a csv
cleaned_pers_df.to_csv(r"Output/person_final.csv", index=False, header=True)
