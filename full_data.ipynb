# %%
# importing libraries
import pandas as pd
import glob as glob

# accidents.join(df2, how='outer')

# pd.concat([pd.read_csv(f).set_index('Case_Number') for f in glob.glob('Output/*.csv')],
#             axis=1).reset_index(drop=True)

# files = glob.glob('/Users/thomaslawless/Desktop/Ga Tech/Homework/Crash-Dummies-2.0/Output/*.csv')
# all_data = pd.merge(files, how='left')

# reading csv files
accidents = pd.read_csv('Output/accident_final.csv', encoding='cp1252')
people = pd.read_csv('Output/person_final.csv', encoding='cp1252')
vehicle = pd.read_csv('Output/vehicles_final.csv', encoding='cp1252')
  
# using merge function by setting how='outer'
some_data = pd.merge(accidents, people,
                    how='outer',
                    on='Case_Number')
  
# displaying result
print(some_data)
# Out:
#          State  Case_Number  Persons       County          City     Month  \
# 0      Alabama        10001      3.0     LEE (81)       OPELIKA  February
# 1      Alabama        10001      3.0     LEE (81)       OPELIKA  February
# 2      Alabama        10002      2.0  ETOWAH (55)       GADSDEN   January
# 3      Alabama        10002      2.0  ETOWAH (55)       GADSDEN   January
# 4      Alabama        10004      1.0  ETOWAH (55)  RAINBOW CITY   January
# ...        ...          ...      ...          ...           ...       ...
# 50165      NaN       560118      NaN          NaN           NaN       NaN
# 50166      NaN       560119      NaN          NaN           NaN       NaN
# 50167      NaN       560120      NaN          NaN           NaN       NaN
# 50168      NaN       560121      NaN          NaN           NaN       NaN
# 50169      NaN       560121      NaN          NaN           NaN       NaN
#
#              Day       Route Rural/Urban   Latitude  ...  \
# 0       Thursday  Interstate       Urban  32.666222  ...
# 1       Thursday  Interstate       Urban  32.666222  ...
# 2      Wednesday  Interstate       Urban  33.997828  ...
# 3      Wednesday  Interstate       Urban  33.997828  ...
# 4        Tuesday  Interstate       Rural  33.956472  ...
# ...          ...         ...         ...        ...  ...
# 50165        NaN         NaN         NaN        NaN  ...
# 50166        NaN         NaN         NaN        NaN  ...
# 50167        NaN         NaN         NaN        NaN  ...
# 50168        NaN         NaN         NaN        NaN  ...
# 50169        NaN         NaN         NaN        NaN  ...
#
#                                      Manner of Collision    Light Conditions  \
# 0                                          Front-to-Rear            Daylight
# 1                                          Front-to-Rear            Daylight
# 2                                          Front-to-Rear  Dark - Not Lighted
# 3                                          Front-to-Rear  Dark - Not Lighted
# 4      The First Harmful Event was Not a Collision wi...  Dark - Not Lighted
# ...                                                  ...                 ...
# 50165                                                NaN                 NaN
# 50166                                                NaN                 NaN
# 50167                                                NaN                 NaN
# 50168                                                NaN                 NaN
# 50169                                                NaN                 NaN
#
#       Weather    Vehicle_Model  \
# 0       Clear           Toyota
# 1       Clear     Freightliner
# 2        Rain              BMW
# 3        Rain        Chevrolet
# 4       Clear        Peterbilt
# ...       ...              ...
# 50165     NaN        Peterbilt
# 50166     NaN  Harley-Davidson
# 50167     NaN          Hyundai
# 50168     NaN            Dodge
# 50169     NaN            Dodge
#
#                                          Vehicle_Model.1   AGE     Sex  \
# 0                                           Toyota Camry  34.0  Female
# 1                        Freightliner Medium/Heavy - CBE  59.0    Male
# 2                                           BMW 3-series  42.0  Female
# 3      Chevrolet TrailBlazer (2003 on; for 2002 model...  54.0  Female
# 4                           Peterbilt Medium/Heavy - CBE  41.0    Male
# ...                                                  ...   ...     ...
# 50165                       Peterbilt Medium/Heavy - CBE  56.0    Male
# 50166                   Harley-Davidson 750cc or greater  52.0    Male
# 50167                                   Hyundai Santa Fe  31.0    Male
# 50168  Dodge Dart (2013 on. See model 001 for 1960-19...  42.0    Male
# 50169                                   Dodge Ram Pickup  30.0    Male
#
#            DOA_Status                          Passenger_Type     Age_Group
# 0      Not Applicable  Driver of a Motor Vehicle In-Transport  (29.0, 37.0]
# 1      Not Applicable  Driver of a Motor Vehicle In-Transport  (55.0, 65.0]
# 2       Died at Scene  Driver of a Motor Vehicle In-Transport  (37.0, 46.0]
# 3      Not Applicable  Driver of a Motor Vehicle In-Transport  (46.0, 55.0]
# 4      Not Applicable  Driver of a Motor Vehicle In-Transport  (37.0, 46.0]
# ...               ...                                     ...           ...
# 50165  Not Applicable  Driver of a Motor Vehicle In-Transport  (55.0, 65.0]
# 50166  Not Applicable  Driver of a Motor Vehicle In-Transport  (46.0, 55.0]
# 50167   Died at Scene  Driver of a Motor Vehicle In-Transport  (29.0, 37.0]
# 50168   Died at Scene  Driver of a Motor Vehicle In-Transport  (37.0, 46.0]
# 50169  Not Applicable  Driver of a Motor Vehicle In-Transport  (29.0, 37.0]
#
# [50170 rows x 22 columns]

# %%
full_data = pd.merge(some_data, vehicle,
                        how='left',
                        on='Case_Number')

full_data.head(10)
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54360 entries, 0 to 54359
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                21641 non-null  object
#  1   Case_Number          54360 non-null  int64
#  2   Persons              21641 non-null  float64
#  3   County               21641 non-null  object
#  4   City                 21641 non-null  object
#  5   Month                21641 non-null  object
#  6   Day                  21641 non-null  object
#  7   Route                21641 non-null  object
#  8   Rural/Urban          21641 non-null  object
#  9   Latitude             21641 non-null  float64
#  10  Longitude            21641 non-null  float64
#  11  First Harmful Event  21641 non-null  object
#  12  Manner of Collision  21641 non-null  object
#  13  Light Conditions     21641 non-null  object
#  14  Weather              21641 non-null  object
#  15  Vehicle_Model        53854 non-null  object
#  16  Vehicle_Model.1      53854 non-null  object
#  17  AGE                  53854 non-null  float64
#  18  Sex                  53854 non-null  object
#  19  DOA_Status           53854 non-null  object
#  20  Passenger_Type       53854 non-null  object
#  21  Age_Group            53854 non-null  object
#  22  Vehicle No.          35160 non-null  float64
#  23  Body Type            35160 non-null  object
#  24  Speed Exceed         35160 non-null  object
#  25  Driver Safety        35160 non-null  object
#  26  Pedestrian Crash     35160 non-null  object
#  27  Hit/Run              35160 non-null  object
# dtypes: float64(5), int64(1), object(22)
# memory usage: 12.0+ MB

# %%
clean_df = full_data[~full_data.isin(["NOT APPLICABLE", "Not Reported", "Unknown", "Other", "NaN", "non-null", "Non-Null"]).any(axis=1)]
# clean_df = full_data.dropna(inplace=True)
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54274 entries, 0 to 54359
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                21616 non-null  object
#  1   Case_Number          54274 non-null  int64
#  2   Persons              21616 non-null  float64
#  3   County               21616 non-null  object
#  4   City                 21616 non-null  object
#  5   Month                21616 non-null  object
#  6   Day                  21616 non-null  object
#  7   Route                21616 non-null  object
#  8   Rural/Urban          21616 non-null  object
#  9   Latitude             21616 non-null  float64
#  10  Longitude            21616 non-null  float64
#  11  First Harmful Event  21616 non-null  object
#  12  Manner of Collision  21616 non-null  object
#  13  Light Conditions     21616 non-null  object
#  14  Weather              21616 non-null  object
#  15  Vehicle_Model        53772 non-null  object
#  16  Vehicle_Model.1      53772 non-null  object
#  17  AGE                  53772 non-null  float64
#  18  Sex                  53772 non-null  object
#  19  DOA_Status           53772 non-null  object
#  20  Passenger_Type       53772 non-null  object
#  21  Age_Group            53772 non-null  object
#  22  Vehicle No.          35074 non-null  float64
#  23  Body Type            35074 non-null  object
#  24  Speed Exceed         35074 non-null  object
#  25  Driver Safety        35074 non-null  object
#  26  Pedestrian Crash     35074 non-null  object
#  27  Hit/Run              35074 non-null  object
# dtypes: float64(5), int64(1), object(22)
# memory usage: 12.0+ MB

# %%
clean_df.head(50)
# Out:
#       State  Case_Number  Persons            County          City     Month  \
# 0   Alabama        10001      3.0          LEE (81)       OPELIKA  February
# 1   Alabama        10001      3.0          LEE (81)       OPELIKA  February
# 2   Alabama        10002      2.0       ETOWAH (55)       GADSDEN   January
# 3   Alabama        10002      2.0       ETOWAH (55)       GADSDEN   January
# 4   Alabama        10004      1.0       ETOWAH (55)  RAINBOW CITY   January
# 5   Alabama        10008      1.0      HOUSTON (69)    COTTONWOOD  February
# 6   Alabama        10009      1.0       BALDWIN (3)   GULF SHORES  February
# 7   Alabama        10010      1.0  MONTGOMERY (101)    MONTGOMERY  February
# 8   Alabama        10013      1.0      HOUSTON (69)        DOTHAN   January
# 9   Alabama        10015      2.0       BUTLER (13)    GREENVILLE   January
# 10  Alabama        10015      2.0       BUTLER (13)    GREENVILLE   January
# 11  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 12  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 13  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 14  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 15  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 16  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 17  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 18  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 19  Alabama        10016      3.0       MOBILE (97)        MOBILE   January
# 20  Alabama        10017      2.0    JEFFERSON (73)    GARDENDALE   January
# 21  Alabama        10017      2.0    JEFFERSON (73)    GARDENDALE   January
# 22  Alabama        10018      1.0       BALDWIN (3)   GULF SHORES   January
# 23  Alabama        10025      3.0      MADISON (89)    HUNTSVILLE   January
# 24  Alabama        10025      3.0      MADISON (89)    HUNTSVILLE   January
# 25  Alabama        10025      3.0      MADISON (89)    HUNTSVILLE   January
# 26  Alabama        10026      1.0    COVINGTON (39)     RED LEVEL   January
# 27  Alabama        10028      4.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 28  Alabama        10028      4.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 29  Alabama        10028      4.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 30  Alabama        10028      4.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 31  Alabama        10030      1.0      SHELBY (117)        PELHAM   January
# 32  Alabama        10031      2.0      JACKSON (71)    SCOTTSBORO   January
# 33  Alabama        10031      2.0      JACKSON (71)    SCOTTSBORO   January
# 34  Alabama        10033      4.0      MADISON (89)      NEW HOPE   January
# 35  Alabama        10033      4.0      MADISON (89)      NEW HOPE   January
# 36  Alabama        10039      1.0       MOBILE (97)        MOBILE   January
# 37  Alabama        10045      2.0      CULLMAN (43)       CULLMAN   January
# 38  Alabama        10045      2.0      CULLMAN (43)       CULLMAN   January
# 39  Alabama        10047      2.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 40  Alabama        10047      2.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 41  Alabama        10048      1.0       MOBILE (97)        MOBILE   January
# 42  Alabama        10051      2.0       MOBILE (97)        MOBILE   January
# 43  Alabama        10055      3.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 44  Alabama        10055      3.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 45  Alabama        10056      3.0     RUSSELL (113)   PHENIX CITY   January
# 46  Alabama        10056      3.0     RUSSELL (113)   PHENIX CITY   January
# 47  Alabama        10057      1.0  TUSCALOOSA (125)    TUSCALOOSA   January
# 48  Alabama        10058      3.0  MONTGOMERY (101)    MONTGOMERY   January
# 49  Alabama        10061      1.0       DEKALB (49)    RAINSVILLE   January
#
#           Day                        Route Rural/Urban   Latitude  ...  \
# 0    Thursday                   Interstate       Urban  32.666222  ...
# 1    Thursday                   Interstate       Urban  32.666222  ...
# 2   Wednesday                   Interstate       Urban  33.997828  ...
# 3   Wednesday                   Interstate       Urban  33.997828  ...
# 4     Tuesday                   Interstate       Rural  33.956472  ...
# 5    Saturday                  County Road       Rural  31.068686  ...
# 6      Friday  Local Street - Municipality       Urban  30.279125  ...
# 7    Thursday  Local Street - Municipality       Urban  32.344300  ...
# 8      Friday                 U.S. Highway       Urban  31.159875  ...
# 9      Monday                State Highway       Urban  31.848989  ...
# 10     Monday                State Highway       Urban  31.848989  ...
# 11     Monday  Local Street - Municipality       Urban  30.632508  ...
# 12     Monday  Local Street - Municipality       Urban  30.632508  ...
# 13     Monday  Local Street - Municipality       Urban  30.632508  ...
# 14     Monday  Local Street - Municipality       Urban  30.632508  ...
# 15     Monday  Local Street - Municipality       Urban  30.632508  ...
# 16     Monday  Local Street - Municipality       Urban  30.632508  ...
# 17     Monday  Local Street - Municipality       Urban  30.632508  ...
# 18     Monday  Local Street - Municipality       Urban  30.632508  ...
# 19     Monday  Local Street - Municipality       Urban  30.632508  ...
# 20     Monday                 U.S. Highway       Urban  33.655314  ...
# 21     Monday                 U.S. Highway       Urban  33.655314  ...
# 22     Monday                  County Road       Urban  30.297422  ...
# 23     Friday  Local Street - Municipality       Urban  34.749350  ...
# 24     Friday  Local Street - Municipality       Urban  34.749350  ...
# 25     Friday  Local Street - Municipality       Urban  34.749350  ...
# 26     Friday                  County Road       Rural  31.406711  ...
# 27   Saturday                 U.S. Highway       Urban  33.170528  ...
# 28   Saturday                 U.S. Highway       Urban  33.170528  ...
# 29   Saturday                 U.S. Highway       Urban  33.170528  ...
# 30   Saturday                 U.S. Highway       Urban  33.170528  ...
# 31     Monday                 U.S. Highway       Urban  33.285650  ...
# 32    Tuesday                State Highway       Urban  34.628714  ...
# 33    Tuesday                State Highway       Urban  34.628714  ...
# 34   Thursday  Local Street - Municipality       Rural  34.556833  ...
# 35   Thursday  Local Street - Municipality       Rural  34.556833  ...
# 36     Sunday  Local Street - Municipality       Urban  30.600125  ...
# 37     Monday                 U.S. Highway       Urban  34.204322  ...
# 38     Monday                 U.S. Highway       Urban  34.204322  ...
# 39    Tuesday                State Highway       Urban  33.146483  ...
# 40    Tuesday                State Highway       Urban  33.146483  ...
# 41    Tuesday                State Highway       Urban  30.450617  ...
# 42   Saturday                 U.S. Highway       Urban  30.720047  ...
# 43    Tuesday  Local Street - Municipality       Urban  33.212133  ...
# 44    Tuesday  Local Street - Municipality       Urban  33.212133  ...
# 45    Tuesday                 U.S. Highway       Urban  32.437236  ...
# 46    Tuesday                 U.S. Highway       Urban  32.437236  ...
# 47    Tuesday  Local Street - Municipality       Urban  33.185528  ...
# 48  Wednesday  Local Street - Municipality       Urban  32.343792  ...
# 49  Wednesday                  County Road       Rural  34.481075  ...
#
#        Sex      DOA_Status                          Passenger_Type  \
# 0   Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 1     Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 2   Female   Died at Scene  Driver of a Motor Vehicle In-Transport
# 3   Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 4     Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 5     Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 6     Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 7      NaN             NaN                                     NaN
# 8     Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 9     Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 10    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 11  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 12  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 13  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 14  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 15  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 16  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 17  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 18  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 19  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 20    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 21  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 22    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 23    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 24    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 25    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 26    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 27    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 28  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 29    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 30    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 31    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 32  Female   Died at Scene  Driver of a Motor Vehicle In-Transport
# 33    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 34  Female   Died at Scene  Driver of a Motor Vehicle In-Transport
# 35  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 36    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 37  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 38  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 39    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 40  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 41    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 42    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 43  Female   Died at Scene  Driver of a Motor Vehicle In-Transport
# 44    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 45  Female  Not Applicable  Driver of a Motor Vehicle In-Transport
# 46    Male  Not Applicable  Driver of a Motor Vehicle In-Transport
# 47    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 48    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
# 49    Male   Died at Scene  Driver of a Motor Vehicle In-Transport
#
#         Age_Group Vehicle No.  \
# 0    (29.0, 37.0]         NaN
# 1    (55.0, 65.0]         NaN
# 2    (37.0, 46.0]         NaN
# 3    (46.0, 55.0]         NaN
# 4    (37.0, 46.0]         NaN
# 5    (46.0, 55.0]         NaN
# 6   (65.0, 100.0]         NaN
# 7             NaN         NaN
# 8   (5.999, 23.0]         NaN
# 9    (37.0, 46.0]         1.0
# 10   (46.0, 55.0]         1.0
# 11  (65.0, 100.0]         1.0
# 12  (65.0, 100.0]         2.0
# 13  (65.0, 100.0]         3.0
# 14   (37.0, 46.0]         1.0
# 15   (37.0, 46.0]         2.0
# 16   (37.0, 46.0]         3.0
# 17   (55.0, 65.0]         1.0
# 18   (55.0, 65.0]         2.0
# 19   (55.0, 65.0]         3.0
# 20   (23.0, 29.0]         1.0
# 21  (65.0, 100.0]         1.0
# 22   (29.0, 37.0]         NaN
# 23  (5.999, 23.0]         3.0
# 24   (29.0, 37.0]         3.0
# 25   (55.0, 65.0]         3.0
# 26  (65.0, 100.0]         1.0
# 27   (29.0, 37.0]         1.0
# 28   (23.0, 29.0]         1.0
# 29   (23.0, 29.0]         1.0
# 30  (65.0, 100.0]         1.0
# 31   (55.0, 65.0]         NaN
# 32   (46.0, 55.0]         1.0
# 33   (23.0, 29.0]         1.0
# 34   (29.0, 37.0]         1.0
# 35   (37.0, 46.0]         1.0
# 36  (65.0, 100.0]         1.0
# 37   (29.0, 37.0]         1.0
# 38  (65.0, 100.0]         1.0
# 39   (37.0, 46.0]         2.0
# 40   (29.0, 37.0]         2.0
# 41   (37.0, 46.0]         NaN
# 42   (37.0, 46.0]         NaN
# 43   (46.0, 55.0]         1.0
# 44   (23.0, 29.0]         1.0
# 45  (65.0, 100.0]         1.0
# 46   (46.0, 55.0]         1.0
# 47  (65.0, 100.0]         NaN
# 48   (29.0, 37.0]         NaN
# 49   (37.0, 46.0]         1.0
#
#                                             Body Type  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                        Light Pickup
# 10                                       Light Pickup
# 11  Compact Utility (Utility Vehicle Categories "S...
# 12                                       Light Pickup
# 13  Minivan (Chrysler Town and Country, Caravan, G...
# 14  Compact Utility (Utility Vehicle Categories "S...
# 15                                       Light Pickup
# 16  Minivan (Chrysler Town and Country, Caravan, G...
# 17  Compact Utility (Utility Vehicle Categories "S...
# 18                                       Light Pickup
# 19  Minivan (Chrysler Town and Country, Caravan, G...
# 20    Two Wheel Motorcycle (excluding motor scooters)
# 21    Two Wheel Motorcycle (excluding motor scooters)
# 22                                                NaN
# 23                                       Light Pickup
# 24                                       Light Pickup
# 25                                       Light Pickup
# 26                                       Light Pickup
# 27                                       Light Pickup
# 28                                       Light Pickup
# 29                                       Light Pickup
# 30                                       Light Pickup
# 31                                                NaN
# 32      Station Wagon (excluding van and truck based)
# 33      Station Wagon (excluding van and truck based)
# 34                              4-door sedan, hardtop
# 35                              4-door sedan, hardtop
# 36                                       Light Pickup
# 37  Compact Utility (Utility Vehicle Categories "S...
# 38  Compact Utility (Utility Vehicle Categories "S...
# 39      Station Wagon (excluding van and truck based)
# 40      Station Wagon (excluding van and truck based)
# 41                                                NaN
# 42                                                NaN
# 43  Compact Utility (Utility Vehicle Categories "S...
# 44  Compact Utility (Utility Vehicle Categories "S...
# 45                              4-door sedan, hardtop
# 46                              4-door sedan, hardtop
# 47                                                NaN
# 48                                                NaN
# 49                              4-door sedan, hardtop
#
#                  Speed Exceed  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                          No
# 10                         No
# 11                         No
# 12                         No
# 13                         No
# 14                         No
# 15                         No
# 16                         No
# 17                         No
# 18                         No
# 19                         No
# 20  Yes, Exceeded Speed Limit
# 21  Yes, Exceeded Speed Limit
# 22                        NaN
# 23                         No
# 24                         No
# 25                         No
# 26                         No
# 27                         No
# 28                         No
# 29                         No
# 30                         No
# 31                        NaN
# 32                         No
# 33                         No
# 34                         No
# 35                         No
# 36                         No
# 37                         No
# 38                         No
# 39                         No
# 40                         No
# 41                        NaN
# 42                        NaN
# 43                         No
# 44                         No
# 45                         No
# 46                         No
# 47                        NaN
# 48                        NaN
# 49  Yes, Exceeded Speed Limit
#
#                                         Driver Safety  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                 Improper Lane Usage
# 10                                Improper Lane Usage
# 11                      Failure to Yield Right-of-Way
# 12  Driver Has a Driving Record or Driver`s Licens...
# 13  Driver Has a Driving Record or Driver`s Licens...
# 14                      Failure to Yield Right-of-Way
# 15  Driver Has a Driving Record or Driver`s Licens...
# 16  Driver Has a Driving Record or Driver`s Licens...
# 17                      Failure to Yield Right-of-Way
# 18  Driver Has a Driving Record or Driver`s Licens...
# 19  Driver Has a Driving Record or Driver`s Licens...
# 20                     Aggressive Driving / Road Rage
# 21                     Aggressive Driving / Road Rage
# 22                                                NaN
# 23  Driver Has a Driving Record or Driver`s Licens...
# 24  Driver Has a Driving Record or Driver`s Licens...
# 25  Driver Has a Driving Record or Driver`s Licens...
# 26  Driver Has a Driving Record or Driver`s Licens...
# 27  Failure to Obey Actual Traffic Sign,Traffic Co...
# 28  Failure to Obey Actual Traffic Sign,Traffic Co...
# 29  Failure to Obey Actual Traffic Sign,Traffic Co...
# 30  Failure to Obey Actual Traffic Sign,Traffic Co...
# 31                                                NaN
# 32                                Improper Lane Usage
# 33                                Improper Lane Usage
# 34                                Improper Lane Usage
# 35                                Improper Lane Usage
# 36                                Improper Lane Usage
# 37  Failure to Obey Actual Traffic Sign,Traffic Co...
# 38  Failure to Obey Actual Traffic Sign,Traffic Co...
# 39  Driver Has a Driving Record or Driver`s Licens...
# 40  Driver Has a Driving Record or Driver`s Licens...
# 41                                                NaN
# 42                                                NaN
# 43                      Failure to Yield Right-of-Way
# 44                      Failure to Yield Right-of-Way
# 45  Driver Has a Driving Record or Driver`s Licens...
# 46  Driver Has a Driving Record or Driver`s Licens...
# 47                                                NaN
# 48                                                NaN
# 49                                     Overcorrecting
#
#                                      Pedestrian Crash Hit/Run
# 0                                                 NaN     NaN
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4                                                 NaN     NaN
# 5                                                 NaN     NaN
# 6                                                 NaN     NaN
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9      Over the lane line on left side of travel lane      No
# 10     Over the lane line on left side of travel lane      No
# 11                           Unknown travel direction      No
# 12             From driveway, intended path not known      No
# 13             From driveway, intended path not known      No
# 14                           Unknown travel direction      No
# 15             From driveway, intended path not known      No
# 16             From driveway, intended path not known      No
# 17                           Unknown travel direction      No
# 18             From driveway, intended path not known      No
# 19             From driveway, intended path not known      No
# 20       From opposite direction  over left lane line      No
# 21       From opposite direction  over left lane line      No
# 22                                                NaN     NaN
# 23  From adjacent lane (same direction) over left ...      No
# 24  From adjacent lane (same direction) over left ...      No
# 25  From adjacent lane (same direction) over left ...      No
# 26         Off the edge of the road on the right side      No
# 27           Crossing over (passing through) Junction      No
# 28           Crossing over (passing through) Junction      No
# 29           Crossing over (passing through) Junction      No
# 30           Crossing over (passing through) Junction      No
# 31                                                NaN     NaN
# 32     Over the lane line on left side of travel lane      No
# 33     Over the lane line on left side of travel lane      No
# 34     Over the lane line on left side of travel lane      No
# 35     Over the lane line on left side of travel lane      No
# 36                                     Object in road      No
# 37           Crossing over (passing through) Junction      No
# 38           Crossing over (passing through) Junction      No
# 39                                 Pedestrian in road      No
# 40                                 Pedestrian in road      No
# 41                                                NaN     NaN
# 42                                                NaN     NaN
# 43                                       Turning Left      No
# 44                                       Turning Left      No
# 45           Crossing over (passing through) Junction      No
# 46           Crossing over (passing through) Junction      No
# 47                                                NaN     NaN
# 48                                                NaN     NaN
# 49         Off the edge of the road on the right side      No
#
# [50 rows x 28 columns]
